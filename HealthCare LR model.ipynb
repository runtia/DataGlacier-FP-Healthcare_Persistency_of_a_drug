# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
healthcare = pd.ExcelFile("Healthcare.xlsx")

# %%
df = pd.read_excel(healthcare, 'Dataset')

# %%
df.head()
# Out:
#   Ptid Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0   P1       Persistent    Male      Caucasian  Not Hispanic     West
# 1   P2   Non-Persistent    Male          Asian  Not Hispanic     West
# 2   P3   Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3   P4   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4   P5   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
#
#   Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0        >75  GENERAL PRACTITIONER              Others
# 1      55-65  GENERAL PRACTITIONER              Others
# 2      65-75  GENERAL PRACTITIONER              Others
# 3        >75  GENERAL PRACTITIONER              Others
# 4        >75  GENERAL PRACTITIONER              Others
#
#        Ntm_Speciality_Bucket  ... Risk_Family_History_Of_Osteoporosis  \
# 0  OB/GYN/Others/PCP/Unknown  ...                                   N
# ...

# %%
df.dtypes
# Out:
# Ptid                              object
# Persistency_Flag                  object
# Gender                            object
# Race                              object
# Ethnicity                         object
#                                    ...
# Risk_Hysterectomy_Oophorectomy    object
# Risk_Estrogen_Deficiency          object
# Risk_Immobilization               object
# Risk_Recurring_Falls              object
# Count_Of_Risks                     int64
# Length: 69, dtype: object

# %%
df = df.drop(["Ptid"], axis = 1)

# %%
df
# Out:
#      Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0          Persistent    Male      Caucasian  Not Hispanic     West
# 1      Non-Persistent    Male          Asian  Not Hispanic     West
# 2      Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3      Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4      Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# ...               ...     ...            ...           ...      ...
# 3419       Persistent  Female      Caucasian  Not Hispanic    South
# 3420       Persistent  Female      Caucasian  Not Hispanic    South
# 3421       Persistent  Female      Caucasian  Not Hispanic    South
# 3422   Non-Persistent  Female      Caucasian  Not Hispanic    South
# 3423   Non-Persistent  Female      Caucasian  Not Hispanic    South
#
#      Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0           >75  GENERAL PRACTITIONER              Others
# ...

# %%
attributes = df.columns

# %%
attributes
# Out:
# Index(['Persistency_Flag', 'Gender', 'Race', 'Ethnicity', 'Region',
#        'Age_Bucket', 'Ntm_Speciality', 'Ntm_Specialist_Flag',
#        'Ntm_Speciality_Bucket', 'Gluco_Record_Prior_Ntm',
#        'Gluco_Record_During_Rx', 'Dexa_Freq_During_Rx', 'Dexa_During_Rx',
#        'Frag_Frac_Prior_Ntm', 'Frag_Frac_During_Rx', 'Risk_Segment_Prior_Ntm',
#        'Tscore_Bucket_Prior_Ntm', 'Risk_Segment_During_Rx',
#        'Tscore_Bucket_During_Rx', 'Change_T_Score', 'Change_Risk_Segment',
#        'Adherent_Flag', 'Idn_Indicator', 'Injectable_Experience_During_Rx',
#        'Comorb_Encounter_For_Screening_For_Malignant_Neoplasms',
#        'Comorb_Encounter_For_Immunization',
#        'Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx',
#        'Comorb_Vitamin_D_Deficiency',
#        'Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified',
#        'Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx',
# ...

# %%
df.isnull().sum()
# Out:
# Persistency_Flag                  0
# Gender                            0
# Race                              0
# Ethnicity                         0
# Region                            0
#                                  ..
# Risk_Hysterectomy_Oophorectomy    0
# Risk_Estrogen_Deficiency          0
# Risk_Immobilization               0
# Risk_Recurring_Falls              0
# Count_Of_Risks                    0
# Length: 68, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data = df["Dexa_Freq_During_Rx"])
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data = df["Count_Of_Risks"])
sns.set_style('darkgrid')

# %% [markdown]
# # There are some outliers

# %% [markdown]
# # We will keep them, as it is normal to have extreme examples on drug test.

# %% [markdown]
# # As for catagory data, is null() makes no sense

# %%
df = df.replace(to_replace = ['Y','N'],value = ['1','0'])

# %%
df
# Out:
#      Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0          Persistent    Male      Caucasian  Not Hispanic     West
# 1      Non-Persistent    Male          Asian  Not Hispanic     West
# 2      Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3      Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4      Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# ...               ...     ...            ...           ...      ...
# 3419       Persistent  Female      Caucasian  Not Hispanic    South
# 3420       Persistent  Female      Caucasian  Not Hispanic    South
# 3421       Persistent  Female      Caucasian  Not Hispanic    South
# 3422   Non-Persistent  Female      Caucasian  Not Hispanic    South
# 3423   Non-Persistent  Female      Caucasian  Not Hispanic    South
#
#      Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0           >75  GENERAL PRACTITIONER              Others
# ...

# %%
for i in attributes:
    print(i)
    print(pd.unique(df[i]))
# Out:
# Persistency_Flag
# ['Persistent' 'Non-Persistent']
# Gender
# ['Male' 'Female']
# Race
# ['Caucasian' 'Asian' 'Other/Unknown' 'African American']
# Ethnicity
# ['Not Hispanic' 'Hispanic' 'Unknown']
# Region
# ['West' 'Midwest' 'South' 'Other/Unknown' 'Northeast']
# Age_Bucket
# ['>75' '55-65' '65-75' '<55']
# Ntm_Speciality
# ['GENERAL PRACTITIONER' 'Unknown' 'ENDOCRINOLOGY' 'RHEUMATOLOGY'
#  'ONCOLOGY' 'PATHOLOGY' 'OBSTETRICS AND GYNECOLOGY'
#  'PSYCHIATRY AND NEUROLOGY' 'ORTHOPEDIC SURGERY'
#  'PHYSICAL MEDICINE AND REHABILITATION' 'SURGERY AND SURGICAL SPECIALTIES'
#  'PEDIATRICS' 'PULMONARY MEDICINE' 'HEMATOLOGY & ONCOLOGY' 'UROLOGY'
#  'PAIN MEDICINE' 'NEUROLOGY' 'RADIOLOGY' 'GASTROENTEROLOGY'
#  'EMERGENCY MEDICINE' 'PODIATRY' 'OPHTHALMOLOGY' 'OCCUPATIONAL MEDICINE'
#  'TRANSPLANT SURGERY' 'PLASTIC SURGERY' 'CLINICAL NURSE SPECIALIST'
#  'OTOLARYNGOLOGY' 'HOSPITAL MEDICINE' 'ORTHOPEDICS' 'NEPHROLOGY'
#  'GERIATRIC MEDICINE' 'HOSPICE AND PALLIATIVE MEDICINE'
# ...

# %%
pd.unique(df["Ntm_Speciality"])
# Out:
# array(['GENERAL PRACTITIONER', 'Unknown', 'ENDOCRINOLOGY', 'RHEUMATOLOGY',
#        'ONCOLOGY', 'PATHOLOGY', 'OBSTETRICS AND GYNECOLOGY',
#        'PSYCHIATRY AND NEUROLOGY', 'ORTHOPEDIC SURGERY',
#        'PHYSICAL MEDICINE AND REHABILITATION',
#        'SURGERY AND SURGICAL SPECIALTIES', 'PEDIATRICS',
#        'PULMONARY MEDICINE', 'HEMATOLOGY & ONCOLOGY', 'UROLOGY',
#        'PAIN MEDICINE', 'NEUROLOGY', 'RADIOLOGY', 'GASTROENTEROLOGY',
#        'EMERGENCY MEDICINE', 'PODIATRY', 'OPHTHALMOLOGY',
#        'OCCUPATIONAL MEDICINE', 'TRANSPLANT SURGERY', 'PLASTIC SURGERY',
#        'CLINICAL NURSE SPECIALIST', 'OTOLARYNGOLOGY', 'HOSPITAL MEDICINE',
#        'ORTHOPEDICS', 'NEPHROLOGY', 'GERIATRIC MEDICINE',
#        'HOSPICE AND PALLIATIVE MEDICINE',
#        'OBSTETRICS & OBSTETRICS & GYNECOLOGY & OBSTETRICS & GYNECOLOGY',
#        'VASCULAR SURGERY', 'CARDIOLOGY', 'NUCLEAR MEDICINE'], dtype=object)

# %%
pd.unique(df["Age_Bucket"])
# Out:
# array(['>75', '55-65', '65-75', '<55'], dtype=object)

# %%
df.groupby(["Gender"]).count()
# Out:
#         Persistency_Flag  Race  Ethnicity  Region  Age_Bucket  Ntm_Speciality  \
# Gender
# Female              3230  3230       3230    3230        3230            3230
# Male                 194   194        194     194         194             194
#
#         Ntm_Specialist_Flag  Ntm_Speciality_Bucket  Gluco_Record_Prior_Ntm  \
# Gender
# Female                 3230                   3230                    3230
# Male                    194                    194                     194
#
#         Gluco_Record_During_Rx  ...  Risk_Family_History_Of_Osteoporosis  \
# Gender                          ...
# Female                    3230  ...                                 3230
# Male                       194  ...                                  194
#
#         Risk_Low_Calcium_Intake  Risk_Vitamin_D_Insufficiency  \
# Gender
# Female                     3230                          3230
# Male                        194                           194
#
# ...

# %%
df
# Out:
#      Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0          Persistent    Male      Caucasian  Not Hispanic     West
# 1      Non-Persistent    Male          Asian  Not Hispanic     West
# 2      Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3      Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4      Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# ...               ...     ...            ...           ...      ...
# 3419       Persistent  Female      Caucasian  Not Hispanic    South
# 3420       Persistent  Female      Caucasian  Not Hispanic    South
# 3421       Persistent  Female      Caucasian  Not Hispanic    South
# 3422   Non-Persistent  Female      Caucasian  Not Hispanic    South
# 3423   Non-Persistent  Female      Caucasian  Not Hispanic    South
#
#      Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0           >75  GENERAL PRACTITIONER              Others
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='magma')
plt.show()

# %%
ex_of_region = df.groupby('Region').Count_Of_Risks.count()

# %%
plt.figure(figsize=(18,25))
sns.set_style('darkgrid')
plt.pie(x=ex_of_region.values,labels=ex_of_region.index,autopct='%.1f%%',textprops={'fontsize': 14})
plt.show()

# %%
risk_of_0 = df[df['Count_Of_Risks']==0].groupby(['Age_Bucket']).Count_Of_Risks.count()
risk_of_1 = df[df['Count_Of_Risks']==1].groupby(['Age_Bucket']).Count_Of_Risks.count()
risk_of_2 = df[df['Count_Of_Risks']==2].groupby(['Age_Bucket']).Count_Of_Risks.count()

# %%
risk_of_0
# Out:
# Age_Bucket
# 55-65    198
# 65-75    314
# <55       47
# >75      411
# Name: Count_Of_Risks, dtype: int64

# %%
risk_of_1
# Out:
# Age_Bucket
# 55-65    271
# 65-75    376
# <55       61
# >75      534
# Name: Count_Of_Risks, dtype: int64

# %%
risk_of_2
# Out:
# Age_Bucket
# 55-65    162
# 65-75    247
# <55       38
# >75      334
# Name: Count_Of_Risks, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.set_style('darkgrid')
ax = plt.subplot(111)
ax.bar(risk_of_0.index,risk_of_0.values, width=0.3, color='Orange', align='edge',label="0")
plt.title('Number of risk group by age bucket',fontsize = 12)
plt.xlabel('Age Bucket', fontsize = 10)
plt.ylabel('No. risk',fontsize = 10)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.set_style('darkgrid')
ax = plt.subplot(111)
ax.bar(risk_of_1.index,risk_of_1.values, width=0.3, color='Pink', align='center',label="1")
plt.title('Number of risk group by age bucket',fontsize = 12)
plt.xlabel('Age Bucket', fontsize = 10)
plt.ylabel('No. risk',fontsize = 10)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.set_style('darkgrid')
ax = plt.subplot(111)
ax.bar(risk_of_2.index,risk_of_2.values, width=0.3, color='Red', align='center',label="2")
plt.title('Number of risk group by age bucket',fontsize = 12)
plt.xlabel('Age Bucket', fontsize = 10)
plt.ylabel('No. risk',fontsize = 10)
plt.legend()
plt.show()

# %%
df["Gender"] = df["Gender"].replace(to_replace = ['Male','Female'],value = ['1','0'])

# %%
df
# Out:
#      Persistency_Flag Gender           Race     Ethnicity   Region Age_Bucket  \
# 0          Persistent      1      Caucasian  Not Hispanic     West        >75
# 1      Non-Persistent      1          Asian  Not Hispanic     West      55-65
# 2      Non-Persistent      0  Other/Unknown      Hispanic  Midwest      65-75
# 3      Non-Persistent      0      Caucasian  Not Hispanic  Midwest        >75
# 4      Non-Persistent      0      Caucasian  Not Hispanic  Midwest        >75
# ...               ...    ...            ...           ...      ...        ...
# 3419       Persistent      0      Caucasian  Not Hispanic    South        >75
# 3420       Persistent      0      Caucasian  Not Hispanic    South        >75
# 3421       Persistent      0      Caucasian  Not Hispanic    South        >75
# 3422   Non-Persistent      0      Caucasian  Not Hispanic    South      55-65
# 3423   Non-Persistent      0      Caucasian  Not Hispanic    South      65-75
#
# ...

# %%
df["Age_Bucket"] = df["Age_Bucket"].replace(to_replace = ['>75','55-65','65-75','<55'], value = [80,60,70,50])

# %%
df["Persistency_Flag"]= df["Persistency_Flag"].replace(to_replace = ['Persistent', 'Non-Persistent'], value = [1,0])

# %%
sns.jointplot(x="Age_Bucket",y="Count_Of_Risks",data = df)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[["Persistency_Flag","Gender","Age_Bucket","Gluco_Record_Prior_Ntm","Risk_Family_History_Of_Osteoporosis","Risk_Low_Calcium_Intake","Risk_Vitamin_D_Insufficiency","Risk_Poor_Health_Frailty","Risk_Excessive_Thinness","Risk_Hysterectomy_Oophorectomy","Risk_Estrogen_Deficiency","Risk_Immobilization"]]

# %%
X
# Out:
#       Persistency_Flag Gender  Age_Bucket Gluco_Record_Prior_Ntm  \
# 0                    1      1          80                      0
# 1                    0      1          60                      0
# 2                    0      0          70                      0
# 3                    0      0          80                      0
# 4                    0      0          80                      1
# ...                ...    ...         ...                    ...
# 3419                 1      0          80                      0
# 3420                 1      0          80                      0
# 3421                 1      0          80                      0
# 3422                 0      0          60                      0
# 3423                 0      0          70                      1
#
#      Risk_Family_History_Of_Osteoporosis Risk_Low_Calcium_Intake  \
# 0                                      0                       0
# ...

# %%
y=df['Count_Of_Risks']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# D:\Anaconda\envs\py39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions =lr.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.76       318
#            1       0.53      0.55      0.54       412
#            2       0.38      0.28      0.32       250
#            3       0.33      0.04      0.06       113
#            4       0.00      0.00      0.00        29
#            5       0.00      0.00      0.00         5
#            6       0.00      0.00      0.00         2
#            7       0.00      0.00      0.00         1
#
#     accuracy                           0.54      1130
#    macro avg       0.23      0.23      0.21      1130
# weighted avg       0.48      0.54      0.49      1130
# D:\Anaconda\envs\py39\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(confusion_matrix(y_test,predict))
